# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys,os
import numpy as np
import matplotlib.pyplot as plt

sys.path.append("../run/")
from run import run_scan

# %% [markdown]
# ## Float $N_D$, $z_0$ and $\beta$

# %%
fixed_params = ['n','sigma','alpha','Lmax_disk', 'Lmax_bulge','N_bulge']
fixed_param_vals = [2.35,1.528,2.6,1.0e36,1.0e36,0]

floated_params = ['N_disk', 'z0', 'beta']
floated_param_priors = [[0,3000000],[0.01,2.0],[1.1,3.0]]

rs_nd = run_scan(fixed_params, fixed_param_vals, floated_params, floated_param_priors, Ns = 200, Nang = 10, share_betas=True, use_prior=True)

# %%
chains_dir = '/group/hepheno/smsharma/GCE-2FIG-bsafdi/run/chains/rs_nd_fixed_prior_nlive500_fixedmask///'

# %%
lge_nd = rs_nd.get_bestfit_lge(chains_dir=chains_dir)
# Out:
#   analysing data from /group/hepheno/smsharma/GCE-2FIG-bsafdi/run/chains/rs_nd_fixed_prior_nlive500_fixedmask///.txt

# %%
rs_nd.plot_corner(labels = ['$N_D$','$z_0$', '$\\beta$'], chains_dir=chains_dir)
plt.savefig("plots/rs_nd.pdf")

# %%
2*lge_nd
# Out:
# -576.723659375691

# %%
rs_nd.get_bestfit_params(chains_dir)
# Out:
#   analysing data from /group/hepheno/smsharma/GCE-2FIG-bsafdi/run/chains/rs_nd_fixed_prior_nlive500_fixedmask///.txt
# [1596861.3132599834, 0.076106491486778505, 2.1326201959981561]

# %% [markdown]
# ## Float $N_D$, $N_B$, $z_0$ and $\beta$

# %%
fixed_params = ['n','sigma','alpha','Lmax_disk', 'Lmax_bulge']
fixed_param_vals = [2.35,1.528,2.6,1.0e36,1.0e36]

floated_params = ['N_bulge','N_disk','z0', 'beta']
floated_param_priors = [[0,3000000],[0,3000000],[0.01,2.0],[1.1,3.0]]

# %%
rs_nd_nb = run_scan(fixed_params, fixed_param_vals, floated_params, floated_param_priors, Ns = 200, Nang = 10, share_betas=True, use_prior=True)

# %%
chains_dir = '/group/hepheno/smsharma/GCE-2FIG-bsafdi/run/chains/rs_nd_nb_fixed_prior_nlive500_fixedmask//'

# %%
lge_nd_nb = rs_nd_nb.get_bestfit_lge(chains_dir=chains_dir)
# Out:
#   analysing data from /group/hepheno/smsharma/GCE-2FIG-bsafdi/run/chains/rs_nd_nb_fixed_prior_nlive500_fixedmask//.txt

# %%
rs_nd_nb.plot_corner(labels = ['$N_B$','$N_D$','$z_0$','$\\beta$'], chains_dir=chains_dir)
plt.savefig("plots/rs_nd_nb.pdf")

# %%
2*lge_nd_nb
# Out:
# -565.848819896072

# %%
rs_nd_nb.get_bestfit_params(chains_dir)
# Out:
#   analysing data from /group/hepheno/smsharma/GCE-2FIG-bsafdi/run/chains/rs_nd_nb_fixed_prior_nlive500_fixedmask//.txt
# [435107.99969843111,
#  932285.82291295426,
#  0.06333103717245743,
#  2.0912013071873163]

# %%
TS = 2*(lge_nd_nb - lge_nd)
print "TS = ", TS
print np.sqrt(TS), "sigma"
# Out:
# TS =  10.8748394796
# 3.29770215144 sigma

# %% [markdown]
# ## Float $N_D$, $N_B$, $z_0$, $\beta$ and $\alpha$

# %%
fixed_params = ['n','sigma','Lmax_disk', 'Lmax_bulge']
fixed_param_vals = [2.35,1.528,1.0e36,1.0e36]

floated_params = ['N_bulge','N_disk', 'alpha','z0', 'beta']
floated_param_priors = [[0,3000000],[0,3000000],[2.1,5.0],[0.01,2.0],[1.1,3.0]]

# %%
rs_nd_nb_alpha = run_scan(fixed_params, fixed_param_vals, floated_params, floated_param_priors, Ns = 200, Nang = 10, share_betas=True, use_prior=True)

# %%
chains_dir='/group/hepheno/smsharma/GCE-2FIG-bsafdi/run/chains/rs_nd_nb_alpha_fixed_prior_nlive500_fixedmask//'

# %%
lge_nd_nb_alpha = rs_nd_nb_alpha.get_bestfit_lge(chains_dir=chains_dir)
# Out:
#   analysing data from /group/hepheno/smsharma/GCE-2FIG-bsafdi/run/chains/rs_nd_nb_alpha_fixed_prior_nlive500_fixedmask//.txt

# %%
rs_nd_nb_alpha.plot_corner(labels = ['$N_B$','$N_D$','$\\alpha$','$z_0$','$\\beta$'], chains_dir=chains_dir)
plt.savefig("plots/rs_nd_nb_alpha.pdf")

# %%
2*lge_nd_nb_alpha
# Out:
# -565.7493727743348

# %%
rs_nd_nb_alpha.get_bestfit_params(chains_dir)
# Out:
#   analysing data from /group/hepheno/smsharma/GCE-2FIG-bsafdi/run/chains/rs_nd_nb_alpha_fixed_prior_nlive500_fixedmask//.txt
# [629137.50831258064,
#  1132294.2935101155,
#  2.6552959736721644,
#  0.050664978491098953,
#  2.1245053832443261]

# %%
TS = 2*(lge_nd_nb_alpha - lge_nd)
print "TS = ", TS
print np.sqrt(TS), "sigma"
# Out:
# TS =  10.9742866014
# 3.31274608163 sigma
