# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys,os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

######Load in functions
sys.path.append("../python/")
# from LL import ll

sys.path.append("../run/")
from run import run_scan
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fixed_params = ['n','sigma','alpha','z0','beta_bulge','beta_disk']
fixed_param_vals = [2.35,1.528,2.6,0.7,1.2,1.2]

floated_params = ['N_bulge','N_disk']
floated_param_priors = [[0,10000],[0,10000]]

# %%
rs = run_scan(fixed_params, fixed_param_vals, floated_params, floated_param_priors, Ns = 100, Nang = 1)

# %%
rs.perform_scan()
# Out:
# [  2.69905150e+03   2.05787957e+03   2.60000000e+00   2.35000000e+00
#    1.52800000e+00   7.00000000e-01   1.20000000e+00   1.20000000e+00] -329.733004527
# [  8.34367216e+03   3.95095348e+02   2.60000000e+00   2.35000000e+00
#    1.52800000e+00   7.00000000e-01   1.20000000e+00   1.20000000e+00] -455.534930308
# [  6.42103136e+03   3.60429227e+03   2.60000000e+00   2.35000000e+00
#    1.52800000e+00   7.00000000e-01   1.20000000e+00   1.20000000e+00] -440.353947695
# [  6.54660404e+03   1.04412138e+03   2.60000000e+00   2.35000000e+00
#    1.52800000e+00   7.00000000e-01   1.20000000e+00   1.20000000e+00] -409.214636002
# [  9.73360062e+03   2.04275310e+03   2.60000000e+00   2.35000000e+00
#    1.52800000e+00   7.00000000e-01   1.20000000e+00   1.20000000e+00] -508.885243934
# [  6.23853624e+03   9.95474517e+03   2.60000000e+00   2.35000000e+00
#    1.52800000e+00   7.00000000e-01   1.20000000e+00   1.20000000e+00] -560.301505105
# ...

# %%
# Basic modules
import numpy as np
import matplotlib.pyplot as plt
import corner 

chains_dir = '/group/hepheno/smsharma/GCE-2FIG-Ben/run/chains/base'

# Load the samples
chain_file = chains_dir + 'post_equal_weights.dat'
samples = np.array(np.loadtxt(chain_file)[:, :-1])

# Now make a triangle plot using corner
corner.corner(samples, labels=['$N_\mathrm{B}$','$N_\mathrm{D}$'], smooth=1.5,
              smooth1d=1, quantiles=[0.16, 0.5, 0.84], show_titles=True,
              title_fmt='.2f', title_args={'fontsize': 14},
              range=[1 for _ in range(2)],
              plot_datapoints=False, verbose=False)
